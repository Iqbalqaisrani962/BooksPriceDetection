# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Selling_Price Deliver_Charges Seller_Rating Shipping_Timing_Rating  \
# 0       Rs. 300            Free           98%                    97%
# 1       Rs. 400            Free           82%                   100%
# 2       Rs. 628          Rs. 99           80%                   100%
# 3       Rs. 250            Free           81%                   100%
# 4       Rs. 899            Free           87%                   100%
#
#   Discount_Percentage Original_Price Chat_Responce_Rate
# 0           Not Found      Not Found               100%
# 1                -55%        Rs. 895                86%
# 2                -58%      Rs. 1,500                97%
# 3                -75%        Rs. 999               100%
# 4                -80%      Rs. 4,499               100%

# %%
df = df[['Title', 'People_Review', 'Deliver_Charges', 'Seller_Rating', 'Shipping_Timing_Rating', 'Discount_Percentage', 'Selling_Price', 'Original_Price', 'Chat_Responce_Rate']]
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0            Free           98%                    97%           Not Found
# 1            Free           82%                   100%                -55%
# 2          Rs. 99           80%                   100%                -58%
# 3            Free           81%                   100%                -75%
# 4            Free           87%                   100%                -80%
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0       Rs. 300      Not Found               100%
# 1       Rs. 400        Rs. 895                86%
# 2       Rs. 628      Rs. 1,500                97%
# 3       Rs. 250        Rs. 999               100%
# 4       Rs. 899      Rs. 4,499               100%

# %%
df = df.replace({'Deliver_Charges': {'Free':np.NaN}})
df = df.replace({'Discount_Percentage': {'Not Found':np.NaN}})
df = df.replace({'Original_Price': {'Not Found':np.NaN}})
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0             NaN           98%                    97%                 NaN
# 1             NaN           82%                   100%                -55%
# 2          Rs. 99           80%                   100%                -58%
# 3             NaN           81%                   100%                -75%
# 4             NaN           87%                   100%                -80%
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0       Rs. 300            NaN               100%
# 1       Rs. 400        Rs. 895                86%
# 2       Rs. 628      Rs. 1,500                97%
# 3       Rs. 250        Rs. 999               100%
# 4       Rs. 899      Rs. 4,499               100%

# %%
# Removing digits and special characters from the digits values
df['People_Review'] = df['People_Review'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Selling_Price'] = df['Selling_Price'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Seller_Rating'] = df['Seller_Rating'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Shipping_Timing_Rating'] = df['Shipping_Timing_Rating'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Chat_Responce_Rate'] = df['Chat_Responce_Rate'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Deliver_Charges'] = df['Deliver_Charges'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Discount_Percentage'] = df['Discount_Percentage'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\-\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Original_Price'] = df['Original_Price'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df.head(15)
# Out:
#                                                 Title People_Review  \
# 0   World Times The Political World Map Edited by ...          100
# 1                thik grow and rich#rich dad poor dad           61
# 2   Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3        The Silent Patient Novel by Alex Michaelides           43
# 4   Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
# 5   twisted #book1 love #2 game#3 hate#4lies combo...           12
# 6   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...          138
# 7               The 48 Laws of Power by Robert Greene           93
# 8   Beyond the Story: 10-Year Record of BTS Book b...           65
# 9            The Psychology of Money by Morgan Housel          135
# 10                           verity by Colleen Hoover          108
# 11                            the psychology of money           39
# 12  it startswith us #it ends withus by Colleen Ho...           13
# 13  Yaaram Yaram Complete Novel by Sumaira Hameed ...           35
# 14                     it end with us by Collen hover           86
#
#    Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0              NaN            98                     97                 NaN
# 1              NaN            82                    100                  55
# 2               99            80                    100                  58
# 3              NaN            81                    100                  75
# 4              NaN            87                    100                  80
# 5              NaN            88                    100                 NaN
# 6               99            89                    100                  11
# 7               99            91                    100                  17
# 8               99            89                    100                  35
# 9              NaN            87                    100                  81
# 10             NaN            88                    100                  12
# 11             NaN            82                    100                  75
# 12             NaN            82                    100                  67
# 13             NaN            87                    100                  55
# 14             NaN            88                    100                 NaN
#
#    Selling_Price Original_Price Chat_Responce_Rate
# 0            300            NaN                100
# 1            400            895                 86
# 2            628           1500                 97
# 3            250            999                100
# 4            899           4499                100
# 5           1045            NaN                 88
# 6            979           1099                 98
# 7            499            599                 91
# 8            587            899                 98
# 9            329           1699                100
# 10           199            225                 88
# 11           225            895                 86
# 12           410           1245                 86
# 13           809           1799                100
# 14           199            NaN                 88

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4081 entries, 0 to 4080
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   4080 non-null   object
#  1   People_Review           4081 non-null   object
#  2   Deliver_Charges         714 non-null    object
#  3   Seller_Rating           4081 non-null   object
#  4   Shipping_Timing_Rating  4081 non-null   object
#  5   Discount_Percentage     3763 non-null   object
#  6   Selling_Price           4081 non-null   object
#  7   Original_Price          3763 non-null   object
#  8   Chat_Responce_Rate      4080 non-null   object
# dtypes: object(9)
# memory usage: 287.1+ KB

# %%
df.describe()
# Out:
#             Title People_Review Deliver_Charges Seller_Rating  \
# count        4080          4081             714          4081
# unique       1574           146              10            27
# top     Not Found                            99            87
# freq           38          1694             457           858
#
#        Shipping_Timing_Rating Discount_Percentage Selling_Price  \
# count                    4081                3763          4081
# unique                     24                  83           407
# top                       100                   1           299
# freq                     2812                 327           221
#
#        Original_Price Chat_Responce_Rate
# count            3763               4080
# unique            164                 30
# top              1999                100
# freq              560               2145

# %%
df = df.replace({'Title': {'Not Found':np.NaN}})

# %%
df['Title'].isna().sum()
# Out:
# 39

# %%
df.isna().sum()
# Out:
# Title                       39
# People_Review                0
# Deliver_Charges           3367
# Seller_Rating                0
# Shipping_Timing_Rating       0
# Discount_Percentage        318
# Selling_Price                0
# Original_Price             318
# Chat_Responce_Rate           1
# dtype: int64

# %%
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...          100
# 1               thik grow and rich#rich dad poor dad           61
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3       The Silent Patient Novel by Alex Michaelides           43
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0             NaN            98                     97                 NaN
# 1             NaN            82                    100                  55
# 2              99            80                    100                  58
# 3             NaN            81                    100                  75
# 4             NaN            87                    100                  80
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0           300            NaN                100
# 1           400            895                 86
# 2           628           1500                 97
# 3           250            999                100
# 4           899           4499                100

# %%
df = df.transpose()
df.head(30)
# Out:
#                                                                      0     \
# Title                   World Times The Political World Map Edited by ...
# People_Review                                                        100
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 97
# Discount_Percentage                                                   NaN
# Selling_Price                                                         300
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                         1     \
# Title                   thik grow and rich#rich dad poor dad
# People_Review                                            61
# Deliver_Charges                                          NaN
# Seller_Rating                                             82
# Shipping_Timing_Rating                                   100
# Discount_Percentage                                       55
# Selling_Price                                            400
# Original_Price                                           895
# Chat_Responce_Rate                                        86
#
#                                                                      2     \
# Title                   Peer e Kamil By umer Ahmed Best Selling Urdu Book
# People_Review                                                        113
# Deliver_Charges                                                        99
# Seller_Rating                                                          80
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    58
# Selling_Price                                                         628
# Original_Price                                                       1500
# Chat_Responce_Rate                                                     97
#
#                                                                 3     \
# Title                   The Silent Patient Novel by Alex Michaelides
# People_Review                                                    43
# Deliver_Charges                                                  NaN
# Seller_Rating                                                     81
# Shipping_Timing_Rating                                           100
# Discount_Percentage                                               75
# Selling_Price                                                    250
# Original_Price                                                   999
# Chat_Responce_Rate                                               100
#
#                                                                      4     \
# Title                   Rich Dad, Poor Dad / Atomic Habits /Think and ...
# People_Review                                                        238
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          87
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    80
# Selling_Price                                                         899
# Original_Price                                                       4499
# Chat_Responce_Rate                                                    100
#
#                                                                      5     \
# Title                   twisted #book1 love #2 game#3 hate#4lies combo...
# People_Review                                                         12
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          88
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                   NaN
# Selling_Price                                                        1045
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                     88
#
#                                                                      6     \
# Title                   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...
# People_Review                                                        138
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    11
# Selling_Price                                                         979
# Original_Price                                                       1099
# Chat_Responce_Rate                                                     98
#
#                                                          7     \
# Title                   The 48 Laws of Power by Robert Greene
# People_Review                                             93
# Deliver_Charges                                            99
# Seller_Rating                                              91
# Shipping_Timing_Rating                                    100
# Discount_Percentage                                        17
# Selling_Price                                             499
# Original_Price                                            599
# Chat_Responce_Rate                                         91
#
#                                                                      8     \
# Title                   Beyond the Story: 10-Year Record of BTS Book b...
# People_Review                                                         65
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    35
# Selling_Price                                                         587
# Original_Price                                                        899
# Chat_Responce_Rate                                                     98
#
#                                                             9     ...  \
# Title                   The Psychology of Money by Morgan Housel  ...
# People_Review                                               135   ...
# Deliver_Charges                                              NaN  ...
# Seller_Rating                                                 87  ...
# Shipping_Timing_Rating                                       100  ...
# Discount_Percentage                                           81  ...
# Selling_Price                                                329  ...
# Original_Price                                              1699  ...
# Chat_Responce_Rate                                           100  ...
#
#                                                                      4071  \
# Title                   The Forty Rules of Love by Elif Shafak Urdu Ed...
# People_Review                                                         63
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    23
# Selling_Price                                                         880
# Original_Price                                                       1150
# Chat_Responce_Rate                                                    100
#
#                                                                      4072  \
# Title                   You Can Become The Person You Want to be by Dr...
# People_Review                                                         53
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         400
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                        4073  \
# Title                   The power of your subconscious mind
# People_Review                                          412
# Deliver_Charges                                         119
# Seller_Rating                                            96
# Shipping_Timing_Rating                                  100
# Discount_Percentage                                       1
# Selling_Price                                           593
# Original_Price                                          599
# Chat_Responce_Rate                                       68
#
#                                                                   4074  \
# Title                   The Prince by Niccolo Machiavelli Urdu Edition
# People_Review                                                       5
# Deliver_Charges                                                    NaN
# Seller_Rating                                                       98
# Shipping_Timing_Rating                                              98
# Discount_Percentage                                                NaN
# Selling_Price                                                      400
# Original_Price                                                     NaN
# Chat_Responce_Rate                                                 100
#
#                                                              4075  \
# Title                   Simple Trading Book I Simple Trading Book
# People_Review                                                  4
# Deliver_Charges                                                99
# Seller_Rating                                                  89
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            73
# Selling_Price                                                1348
# Original_Price                                               5000
# Chat_Responce_Rate                                             87
#
#                                                              4076  \
# Title                   The Laws of Human Nature By Robert Greene
# People_Review                                                  6
# Deliver_Charges                                               NaN
# Seller_Rating                                                  87
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            78
# Selling_Price                                                 445
# Original_Price                                               1999
# Chat_Responce_Rate                                            100
#
#                                                                      4077  \
# Title                   Haraf Haraf Haqeeqat Urdu Book By Wasif Ali Wasif
# People_Review                                                          3
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         500
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                                      4078  \
# Title                   Shayad By Jon Elia in urdu Poetry Book Best Se...
# People_Review                                                        465
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                     1
# Selling_Price                                                         395
# Original_Price                                                        399
# Chat_Responce_Rate                                                     99
#
#                                                    4079  \
# Title                   Simple Trading Book(Novel Size)
# People_Review                                        4
# Deliver_Charges                                     NaN
# Seller_Rating
# Shipping_Timing_Rating                              100
# Discount_Percentage                                  20
# Selling_Price                                       682
# Original_Price                                      850
# Chat_Responce_Rate                                   93
#
#                                                                      4080
# Title                   Abraham Lincoln a Book By Sterling North Urdu ...
# People_Review
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    25
# Selling_Price                                                         300
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
# [9 rows x 4081 columns]

# %%
# Use a conditional statement to replace NaN values in the selected row with values from the row above
df.iloc[7] = df.iloc[6].where(df.iloc[7].isna(), df.iloc[7])
df.head(30)
# Out:
#                                                                      0     \
# Title                   World Times The Political World Map Edited by ...
# People_Review                                                        100
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 97
# Discount_Percentage                                                   NaN
# Selling_Price                                                         300
# Original_Price                                                        300
# Chat_Responce_Rate                                                    100
#
#                                                         1     \
# Title                   thik grow and rich#rich dad poor dad
# People_Review                                            61
# Deliver_Charges                                          NaN
# Seller_Rating                                             82
# Shipping_Timing_Rating                                   100
# Discount_Percentage                                       55
# Selling_Price                                            400
# Original_Price                                           895
# Chat_Responce_Rate                                        86
#
#                                                                      2     \
# Title                   Peer e Kamil By umer Ahmed Best Selling Urdu Book
# People_Review                                                        113
# Deliver_Charges                                                        99
# Seller_Rating                                                          80
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    58
# Selling_Price                                                         628
# Original_Price                                                       1500
# Chat_Responce_Rate                                                     97
#
#                                                                 3     \
# Title                   The Silent Patient Novel by Alex Michaelides
# People_Review                                                    43
# Deliver_Charges                                                  NaN
# Seller_Rating                                                     81
# Shipping_Timing_Rating                                           100
# Discount_Percentage                                               75
# Selling_Price                                                    250
# Original_Price                                                   999
# Chat_Responce_Rate                                               100
#
#                                                                      4     \
# Title                   Rich Dad, Poor Dad / Atomic Habits /Think and ...
# People_Review                                                        238
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          87
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    80
# Selling_Price                                                         899
# Original_Price                                                       4499
# Chat_Responce_Rate                                                    100
#
#                                                                      5     \
# Title                   twisted #book1 love #2 game#3 hate#4lies combo...
# People_Review                                                         12
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          88
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                   NaN
# Selling_Price                                                        1045
# Original_Price                                                       1045
# Chat_Responce_Rate                                                     88
#
#                                                                      6     \
# Title                   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...
# People_Review                                                        138
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    11
# Selling_Price                                                         979
# Original_Price                                                       1099
# Chat_Responce_Rate                                                     98
#
#                                                          7     \
# Title                   The 48 Laws of Power by Robert Greene
# People_Review                                             93
# Deliver_Charges                                            99
# Seller_Rating                                              91
# Shipping_Timing_Rating                                    100
# Discount_Percentage                                        17
# Selling_Price                                             499
# Original_Price                                            599
# Chat_Responce_Rate                                         91
#
#                                                                      8     \
# Title                   Beyond the Story: 10-Year Record of BTS Book b...
# People_Review                                                         65
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    35
# Selling_Price                                                         587
# Original_Price                                                        899
# Chat_Responce_Rate                                                     98
#
#                                                             9     ...  \
# Title                   The Psychology of Money by Morgan Housel  ...
# People_Review                                               135   ...
# Deliver_Charges                                              NaN  ...
# Seller_Rating                                                 87  ...
# Shipping_Timing_Rating                                       100  ...
# Discount_Percentage                                           81  ...
# Selling_Price                                                329  ...
# Original_Price                                              1699  ...
# Chat_Responce_Rate                                           100  ...
#
#                                                                      4071  \
# Title                   The Forty Rules of Love by Elif Shafak Urdu Ed...
# People_Review                                                         63
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    23
# Selling_Price                                                         880
# Original_Price                                                       1150
# Chat_Responce_Rate                                                    100
#
#                                                                      4072  \
# Title                   You Can Become The Person You Want to be by Dr...
# People_Review                                                         53
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         400
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
#                                                        4073  \
# Title                   The power of your subconscious mind
# People_Review                                          412
# Deliver_Charges                                         119
# Seller_Rating                                            96
# Shipping_Timing_Rating                                  100
# Discount_Percentage                                       1
# Selling_Price                                           593
# Original_Price                                          599
# Chat_Responce_Rate                                       68
#
#                                                                   4074  \
# Title                   The Prince by Niccolo Machiavelli Urdu Edition
# People_Review                                                       5
# Deliver_Charges                                                    NaN
# Seller_Rating                                                       98
# Shipping_Timing_Rating                                              98
# Discount_Percentage                                                NaN
# Selling_Price                                                      400
# Original_Price                                                     400
# Chat_Responce_Rate                                                 100
#
#                                                              4075  \
# Title                   Simple Trading Book I Simple Trading Book
# People_Review                                                  4
# Deliver_Charges                                                99
# Seller_Rating                                                  89
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            73
# Selling_Price                                                1348
# Original_Price                                               5000
# Chat_Responce_Rate                                             87
#
#                                                              4076  \
# Title                   The Laws of Human Nature By Robert Greene
# People_Review                                                  6
# Deliver_Charges                                               NaN
# Seller_Rating                                                  87
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            78
# Selling_Price                                                 445
# Original_Price                                               1999
# Chat_Responce_Rate                                            100
#
#                                                                      4077  \
# Title                   Haraf Haraf Haqeeqat Urdu Book By Wasif Ali Wasif
# People_Review                                                          3
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         500
# Original_Price                                                        500
# Chat_Responce_Rate                                                    100
#
#                                                                      4078  \
# Title                   Shayad By Jon Elia in urdu Poetry Book Best Se...
# People_Review                                                        465
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                     1
# Selling_Price                                                         395
# Original_Price                                                        399
# Chat_Responce_Rate                                                     99
#
#                                                    4079  \
# Title                   Simple Trading Book(Novel Size)
# People_Review                                        4
# Deliver_Charges                                     NaN
# Seller_Rating
# Shipping_Timing_Rating                              100
# Discount_Percentage                                  20
# Selling_Price                                       682
# Original_Price                                      850
# Chat_Responce_Rate                                   93
#
#                                                                      4080
# Title                   Abraham Lincoln a Book By Sterling North Urdu ...
# People_Review
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    25
# Selling_Price                                                         300
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
# [9 rows x 4081 columns]

# %%
df = df.transpose()
df.head(30)
# Out:
#                                                 Title People_Review  \
# 0   World Times The Political World Map Edited by ...          100
# 1                thik grow and rich#rich dad poor dad           61
# 2   Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3        The Silent Patient Novel by Alex Michaelides           43
# 4   Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
# 5   twisted #book1 love #2 game#3 hate#4lies combo...           12
# 6   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...          138
# 7               The 48 Laws of Power by Robert Greene           93
# 8   Beyond the Story: 10-Year Record of BTS Book b...           65
# 9            The Psychology of Money by Morgan Housel          135
# 10                           verity by Colleen Hoover          108
# 11                            the psychology of money           39
# 12  it startswith us #it ends withus by Colleen Ho...           13
# 13  Yaaram Yaram Complete Novel by Sumaira Hameed ...           35
# 14                     it end with us by Collen hover           86
# 15   The Intelligent Investor Book by Benjamin Graham           40
# 16          The Laws of Human Nature by Robert Greene           42
# 17                        ugly love by Colleen hoover           25
# 18                  it ends with us by Colleen Hoover           16
# 19       Peer e Kamil And Aab e Hayaat by umera Ahmed           95
# 20          The Art of Reading Minds by Henrik Fexeus           66
# 21              Peer E Kamil Urdu Book By Umera Ahmad           59
# 22             Haunting Adeline Book by H. D. Carlton           70
# 23            Atomic Habits by James Clear (Original)           37
# 24       Mein Kampf Book by Adolf Hitler Urdu Edition           13
# 25                       Allah_Loves by Omar Suleiman           86
# 26  The 7 Habits of Highly Effective People by Ste...           67
# 27                                                NaN
# 28                                                NaN
# 29   Fourth Wing (The Empyrean, #1) by Rebecca Yarros            6
#
#    Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0              NaN            98                     97                 NaN
# 1              NaN            82                    100                  55
# 2               99            80                    100                  58
# 3              NaN            81                    100                  75
# 4              NaN            87                    100                  80
# 5              NaN            88                    100                 NaN
# 6               99            89                    100                  11
# 7               99            91                    100                  17
# 8               99            89                    100                  35
# 9              NaN            87                    100                  81
# 10             NaN            88                    100                  12
# 11             NaN            82                    100                  75
# 12             NaN            82                    100                  67
# 13             NaN            87                    100                  55
# 14             NaN            88                    100                 NaN
# 15             NaN            87                    100                  74
# 16              99            89                    100                  24
# 17             NaN            82                    100                  31
# 18             NaN            82                    100                  61
# 19             159            80                    100                  50
# 20             NaN            87                    100                  72
# 21              99            81                    100                 NaN
# 22              99            89                    100                  24
# 23             NaN            94                    100                  65
# 24             NaN            98                     97                  26
# 25             NaN            87                    100                  79
# 26             NaN            87                    100                  72
# 27                                                                      NaN
# 28                                                                      NaN
# 29              99            89                    100                  24
#
#    Selling_Price Original_Price Chat_Responce_Rate
# 0            300            300                100
# 1            400            895                 86
# 2            628           1500                 97
# 3            250            999                100
# 4            899           4499                100
# 5           1045           1045                 88
# 6            979           1099                 98
# 7            499            599                 91
# 8            587            899                 98
# 9            329           1699                100
# 10           199            225                 88
# 11           225            895                 86
# 12           410           1245                 86
# 13           809           1799                100
# 14           199            199                 88
# 15           517           1999                100
# 16           455            599                 98
# 17           275            399                 86
# 18           196            499                 86
# 19          1508           3000                 97
# 20           281            999                100
# 21           619            619                100
# 22           533            699                 98
# 23          1395           3995                100
# 24           445            600                100
# 25           375           1799                100
# 26           277            995                100
# 27
# 28
# 29           528            699                 98

# %% [markdown]
# ## Train Test Split

# %%
y = df['Selling_Price']
X = df.drop('Selling_Price', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=54)
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (3264, 3264, 817, 817)

# %%
X_train.head(10)
# Out:
#                                                   Title People_Review  \
# 2173  The Seven Husbands of Evelyn Hugo Novel by Tay...            1
# 2245  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 2367  Aab-E-Hayat urdu novel by Umera Ahmad Aab-E-Ha...          428
# 522                Reclaim Your Heart by Yasmin Mogahed
# 905                              The Darkest Temptation
# 2316  Master Your English – Direct Indirect Narratio...            3
# 1165            The 7 Habits Of Highly Effective People            1
# 1853  Hunting Adeline Novel by H. D. Carlton Best Se...            7
# 2606               Reclaim Your Heart by Yasmin Mogahed
# 1767  How to Stop Worrying and Start Living Book by ...           19
#
#      Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 2173             NaN                                   91                  56
# 2245              99            80                    100                  58
# 2367             NaN            89                     98                   1
# 522              NaN            87                    100                  81
# 905              NaN            86                    100                  70
# 2316             NaN            94                    100                   2
# 1165             NaN            91                     78                  50
# 1853             NaN            89                     98                   1
# 2606             NaN            87                    100                  81
# 1767             NaN            87                    100                  72
#
#      Original_Price Chat_Responce_Rate
# 2173            899                100
# 2245           1500                 97
# 2367            879                 99
# 522            1699                100
# 905             999                 92
# 2316            440                100
# 1165            599                 95
# 1853            379                 99
# 2606           1699                100
# 1767            995                100

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3264 entries, 2173 to 3183
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   3230 non-null   object
#  1   People_Review           3264 non-null   object
#  2   Deliver_Charges         572 non-null    object
#  3   Seller_Rating           3264 non-null   object
#  4   Shipping_Timing_Rating  3264 non-null   object
#  5   Discount_Percentage     3001 non-null   object
#  6   Original_Price          3264 non-null   object
#  7   Chat_Responce_Rate      3263 non-null   object
# dtypes: object(8)
# memory usage: 229.5+ KB

# %%
X_train = X_train.dropna(axis = 0, subset=['Title'], how='any')
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3230 entries, 2173 to 3183
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   3230 non-null   object
#  1   People_Review           3230 non-null   object
#  2   Deliver_Charges         541 non-null    object
#  3   Seller_Rating           3230 non-null   object
#  4   Shipping_Timing_Rating  3230 non-null   object
#  5   Discount_Percentage     2997 non-null   object
#  6   Original_Price          3230 non-null   object
#  7   Chat_Responce_Rate      3230 non-null   object
# dtypes: object(8)
# memory usage: 227.1+ KB

# %%
X_train.head()
# Out:
#                                                   Title People_Review  \
# 2173  The Seven Husbands of Evelyn Hugo Novel by Tay...            1
# 2245  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 2367  Aab-E-Hayat urdu novel by Umera Ahmad Aab-E-Ha...          428
# 522                Reclaim Your Heart by Yasmin Mogahed           NaN
# 905                              The Darkest Temptation           NaN
#
#      Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 2173             NaN           NaN                     91                  56
# 2245              99            80                    100                  58
# 2367             NaN            89                     98                   1
# 522              NaN            87                    100                  81
# 905              NaN            86                    100                  70
#
#      Original_Price Chat_Responce_Rate
# 2173            899                100
# 2245           1500                 97
# 2367            879                 99
# 522            1699                100
# 905             999                 92

# %%
df['Chat_Responce_Rate'].unique()
# Out:
# array(['100', '86', '97', '88', '98', '91', nan, '50', '89', '95', '93',
#        '87', '99', '68', '92', '65', '83', '66', '71', '81', '80', '85',
#        '55', '96', '90', '33', '82', '75'], dtype=object)

# %%
# Replace spaces with NaN values
df['People_Review'] = df['People_Review'].replace('  ', np.nan)
df['Deliver_Charges'] = df['Deliver_Charges'].replace('  ', np.nan)
df['Seller_Rating'] = df['Seller_Rating'].replace('  ', np.nan)
# Replace spaces with NaN values
df['Shipping_Timing_Rating'] = df['Shipping_Timing_Rating'].replace('  ', np.nan)
df['Discount_Percentage'] = df['Discount_Percentage'].replace('  ', np.nan)
df['Original_Price'] = df['Original_Price'].replace('  ', np.nan)
df['Chat_Responce_Rate'] = df['Chat_Responce_Rate'].replace('  ', np.nan)

# %%
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /home/iqbal/project/MLCode.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> X_train['People_Review'] = df['People_Review'].astype(float).astype(int)
#       <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> X_train['Deliver_Charges'] = df['Deliver_Charges'].astype(float).astype(int)
#       <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> X_train['Seller_Rating'] = df['Seller_Rating'].astype(float).astype(int)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:105, in _astype_nansafe(arr, dtype, copy, skipna)
#     100     return lib.ensure_string_array(
#     101         arr, skipna=skipna, convert_na_value=False
#     102     ).reshape(shape)
#     104 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 105     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     107 elif is_object_dtype(arr.dtype):
#     108     # if we have a datetime/timedelta array of objects
#     109     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     111     if is_datetime64_dtype(dtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:150, in _astype_float_to_int_nansafe(values, dtype, copy)
#     146 """
#     147 astype with a check preventing converting NaN to an meaningless integer value.
#     148 """
#     149 if not np.isfinite(values).all():
# --> 150     raise IntCastingNaNError(
#     151         "Cannot convert non-finite values (NA or inf) to integer"
#     152     )
#     153 if dtype.kind == "u":
#     154     # GH#45151
#     155     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
X_train['People_Review'].unique()
X_train = X_train.replace({'People_Review': {'':np.NaN}})
X_train['People_Review'].unique()
# Out:
# array(['1 ', '113 ', '428 ', nan, '3 ', '7 ', '19 ', '13 ', '11 ', '16 ',
#        '51 ', '5 ', '2 ', '48 ', '6 ', '4 ', '63 ', '14 ', '39 ', '10 ',
#        '38 ', '74 ', '12 ', '412 ', '32 ', '9 ', '41 ', '378 ', '127 ',
#        '465 ', '8 ', '15 ', '75 ', '34 ', '1280 ', '52 ', '82 ', '21 ',
#        '35 ', '112 ', '706 ', '108 ', '53 ', '70 ', '26 ', '18 ', '87 ',
#        '40 ', '85 ', '25 ', '95 ', '24 ', '36 ', '28 ', '43 ', '59 ',
#        '478 ', '227 ', '30 ', '17 ', '150 ', '54 ', '55 ', '96 ', '1282 ',
#        '406 ', '83 ', '138 ', '50 ', '86 ', '107 ', '61 ', '93 ', '320 ',
#        '64 ', '177 ', '22 ', '205 ', '145 ', '71 ', '29 ', '98 ', '46 ',
#        '62 ', '182 ', '100 ', '47 ', '1284 ', '60 ', '144 ', '238 ',
#        '23 ', '479 ', '67 ', '44 ', '65 ', '57 ', '66 ', '128 ', '49 ',
#        '208 ', '135 ', '1082 ', '37 ', '166 ', '33 ', '31 ', '206 ',
#        '245 ', '256 ', '597 ', '183 ', '27 ', '131 ', '427 ', '81 ',
#        '72 ', '119 ', '221 ', '97 ', '801 ', '79 ', '255 ', '216 ',
#        '236 ', '169 ', '440 ', '124 ', '173 ', '56 ', '140 ', '141 ',
#        '42 ', '366 ', '20 ', '441 ', '185 ', '1083 ', '254 ', '45 ',
#        '203 ', '139 '], dtype=object)

# %%
y_train = y_train.replace('  ', np.nan)
# y_train = y_train.astype(float).astype(int)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
encoding_trans = Pipeline(steps=
                             [
                                 ('encode', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output = False, dtype = np.int32))
                             ])
inputingDeCh = Pipeline(steps=
                    [
                        ('simpleImZaro', SimpleImputer(missing_values = np.nan, strategy='constant', fill_value=0))
                    ])
inputingPeRe = Pipeline(steps=[
                        ('simpleImMean', SimpleImputer(missing_values = np.nan, strategy = 'most_frequent'))
                    ])

                    
col_trans = ColumnTransformer(transformers=
                              [
                                ('Encoder', encoding_trans,[0]),
                                ('ImputerZero', inputingDeCh, [1, 2, 5]),
                                ('ImputeMean', inputingPeRe, [3,4,7])
                              ])
col_trans.fit(X_train)
x_trained = col_trans.transform(X_train)
X_tested = col_trans.transform(X_test)
# Out:
# /home/iqbal/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:227: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train.head()
# Out:
#                                                   Title People_Review  \
# 2173  The Seven Husbands of Evelyn Hugo Novel by Tay...            1
# 2245  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 2367  Aab-E-Hayat urdu novel by Umera Ahmad Aab-E-Ha...          428
# 522                Reclaim Your Heart by Yasmin Mogahed           NaN
# 905                              The Darkest Temptation           NaN
#
#      Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 2173             NaN           NaN                     91                  56
# 2245              99            80                    100                  58
# 2367             NaN            89                     98                   1
# 522              NaN            87                    100                  81
# 905              NaN            86                    100                  70
#
#      Original_Price Chat_Responce_Rate
# 2173            899                100
# 2245           1500                 97
# 2367            879                 99
# 522            1699                100
# 905             999                 92

# %%
X_train['People_Review'] = df['People_Review'].astype(float).astype(int) 
X_train['Deliver_Charges'] = df['Deliver_Charges'].astype(float).astype(int) 
X_train['Seller_Rating'] = df['Seller_Rating'].astype(float).astype(int) 
X_train['Shipping_Timing_Rating'] = df['Shipping_Timing_Rating'].astype(float).astype(int) 
X_train['Discount_Percentage'] = df['Discount_Percentage'].astype(float).astype(int) 
# X_train['Oirignal_Price'] = df['Original_Price'].astype(float).astype(int) 
X_train['Chat_Responce_Rate'] = df['Chat_Responce_Rate'].astype(float).astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /home/iqbal/project/MLCode.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> X_train['People_Review'] = df['People_Review'].astype(float).astype(int)
#       <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> X_train['Deliver_Charges'] = df['Deliver_Charges'].astype(float).astype(int)
#       <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> X_train['Seller_Rating'] = df['Seller_Rating'].astype(float).astype(int)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:105, in _astype_nansafe(arr, dtype, copy, skipna)
#     100     return lib.ensure_string_array(
#     101         arr, skipna=skipna, convert_na_value=False
#     102     ).reshape(shape)
#     104 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 105     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     107 elif is_object_dtype(arr.dtype):
#     108     # if we have a datetime/timedelta array of objects
#     109     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     111     if is_datetime64_dtype(dtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:150, in _astype_float_to_int_nansafe(values, dtype, copy)
#     146 """
#     147 astype with a check preventing converting NaN to an meaningless integer value.
#     148 """
#     149 if not np.isfinite(values).all():
# --> 150     raise IntCastingNaNError(
#     151         "Cannot convert non-finite values (NA or inf) to integer"
#     152     )
#     153 if dtype.kind == "u":
#     154     # GH#45151
#     155     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
model = Pipeline(steps=[
                        ('preprocessing', col_trans),
                        ('scaling', StandardScaler()),
                        ('regressor', LinearRegression())
                        ])
model.fit(X_train, y_train)

# Step 6: Make Predictions
y_pred = model.predict(X_test)
# Step 7: Evaluate the Model
# Coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

# Evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Coefficients: {coefficients}')
print(f'Intercept: {intercept}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/iqbal/project/MLCode.ipynb Cell 25 line 3
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=20'>21</a> col_trans = ColumnTransformer(transformers=
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=21'>22</a>                               [
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=22'>23</a>                                 ('Encoder', encoding_trans,[0]),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=23'>24</a>                                 ('ImputerZero', inputingDeCh, [1, 2, 5]),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=24'>25</a>                                 ('ImputeMean', inputingPeRe, [3,4,7])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=25'>26</a>                               ])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=26'>27</a> model = Pipeline(steps=[
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=27'>28</a>                         ('preprocessing', col_trans),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=28'>29</a>                         ('scaling', StandardScaler()),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=29'>30</a>                         ('regressor', LinearRegression())
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=30'>31</a>                         ])
# ---> <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=31'>32</a> model.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=33'>34</a> # Step 6: Make Predictions
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X26sZmlsZQ%3D%3D?line=34'>35</a> y_pred = model.predict(X_test)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
#     392 Fit all the transformers one after the other and transform the
#    (...)
#     413     Pipeline with fitted steps.
#     414 """
#     415 fit_params_steps = self._check_fit_params(**fit_params)
# --> 416 Xt = self._fit(X, y, **fit_params_steps)
#     417 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     418     if self._final_estimator != "passthrough":
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:370, in Pipeline._fit(self, X, y, **fit_params_steps)
#     368     cloned_transformer = clone(transformer)
#     369 # Fit or load from cache the current transformer
# --> 370 X, fitted_transformer = fit_transform_one_cached(
#     371     cloned_transformer,
#     372     X,
#     373     y,
#     374     None,
#     375     message_clsname="Pipeline",
#     376     message=self._log_message(step_idx),
#     377     **fit_params_steps[name],
#     378 )
#     379 # Replace the transformer of the step with the fitted
#     380 # transformer. This is necessary when loading the transformer
#     381 # from the cache.
#     382 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:743, in ColumnTransformer.fit_transform(self, X, y)
#     740 self._validate_column_callables(X)
#     741 self._validate_remainder(X)
# --> 743 result = self._fit_transform(X, y, _fit_transform_one)
#     745 if not result:
#     746     self._update_fitted_transformers([])
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:670, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     664 transformers = list(
#     665     self._iter(
#     666         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     667     )
#     668 )
#     669 try:
# --> 670     return Parallel(n_jobs=self.n_jobs)(
#     671         delayed(func)(
#     672             transformer=clone(trans) if not fitted else trans,
#     673             X=_safe_indexing(X, column, axis=1),
#     674             y=y,
#     675             weight=weight,
#     676             message_clsname="ColumnTransformer",
#     677             message=self._log_message(name, idx, len(transformers)),
#     678         )
#     679         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     680     )
#     681 except ValueError as e:
#     682     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:472, in Pipeline.fit_transform(self, X, y, **fit_params)
#     470 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
#     471 if hasattr(last_step, "fit_transform"):
# --> 472     return last_step.fit_transform(Xt, y, **fit_params_last_step)
#     473 else:
#     474     return last_step.fit(Xt, y, **fit_params_last_step).transform(Xt)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
# --> 918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/impute/_base.py:366, in SimpleImputer.fit(self, X, y)
#     348 @_fit_context(prefer_skip_nested_validation=True)
#     349 def fit(self, X, y=None):
#     350     """Fit the imputer on `X`.
#     351
#     352     Parameters
#    (...)
#     364         Fitted estimator.
#     365     """
# --> 366     X = self._validate_input(X, in_fit=True)
#     368     # default fill_value is 0 for numerical input and "missing_value"
#     369     # otherwise
#     370     if self.fill_value is None:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/impute/_base.py:327, in SimpleImputer._validate_input(self, X, in_fit)
#     321 if "could not convert" in str(ve):
#     322     new_ve = ValueError(
#     323         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     324             self.strategy, ve
#     325         )
#     326     )
# --> 327     raise new_ve from None
#     328 else:
#     329     raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: ''
