# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Selling_Price Deliver_Charges Seller_Rating Shipping_Timing_Rating  \
# 0       Rs. 300            Free           98%                    97%
# 1       Rs. 400            Free           82%                   100%
# 2       Rs. 628          Rs. 99           80%                   100%
# 3       Rs. 250            Free           81%                   100%
# 4       Rs. 899            Free           87%                   100%
#
#   Discount_Percentage Original_Price Chat_Responce_Rate
# 0           Not Found      Not Found               100%
# 1                -55%        Rs. 895                86%
# 2                -58%      Rs. 1,500                97%
# 3                -75%        Rs. 999               100%
# 4                -80%      Rs. 4,499               100%

# %%
df = df[['Title', 'People_Review', 'Deliver_Charges', 'Seller_Rating', 'Shipping_Timing_Rating', 'Discount_Percentage', 'Selling_Price', 'Original_Price', 'Chat_Responce_Rate']]
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0            Free           98%                    97%           Not Found
# 1            Free           82%                   100%                -55%
# 2          Rs. 99           80%                   100%                -58%
# 3            Free           81%                   100%                -75%
# 4            Free           87%                   100%                -80%
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0       Rs. 300      Not Found               100%
# 1       Rs. 400        Rs. 895                86%
# 2       Rs. 628      Rs. 1,500                97%
# 3       Rs. 250        Rs. 999               100%
# 4       Rs. 899      Rs. 4,499               100%

# %%
df = df.replace({'Deliver_Charges': {'Free':np.NaN}})
df = df.replace({'Discount_Percentage': {'Not Found':np.NaN}})
df = df.replace({'Original_Price': {'Not Found':np.NaN}})
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...   100 Ratings
# 1               thik grow and rich#rich dad poor dad    61 Ratings
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book   113 Ratings
# 3       The Silent Patient Novel by Alex Michaelides    43 Ratings
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...   238 Ratings
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0             NaN           98%                    97%                 NaN
# 1             NaN           82%                   100%                -55%
# 2          Rs. 99           80%                   100%                -58%
# 3             NaN           81%                   100%                -75%
# 4             NaN           87%                   100%                -80%
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0       Rs. 300            NaN               100%
# 1       Rs. 400        Rs. 895                86%
# 2       Rs. 628      Rs. 1,500                97%
# 3       Rs. 250        Rs. 999               100%
# 4       Rs. 899      Rs. 4,499               100%

# %%
# Removing digits and special characters from the digits values
df['People_Review'] = df['People_Review'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Selling_Price'] = df['Selling_Price'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Seller_Rating'] = df['Seller_Rating'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Shipping_Timing_Rating'] = df['Shipping_Timing_Rating'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Chat_Responce_Rate'] = df['Chat_Responce_Rate'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Deliver_Charges'] = df['Deliver_Charges'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Discount_Percentage'] = df['Discount_Percentage'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\-\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df['Original_Price'] = df['Original_Price'].str.replace(r'[a-zA-Z!@#$%^&*()_+={}\[\]:;"\'<>,.?/\\|`~]', '', regex=True)
df.head(15)
# Out:
#                                                 Title People_Review  \
# 0   World Times The Political World Map Edited by ...          100
# 1                thik grow and rich#rich dad poor dad           61
# 2   Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3        The Silent Patient Novel by Alex Michaelides           43
# 4   Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
# 5   twisted #book1 love #2 game#3 hate#4lies combo...           12
# 6   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...          138
# 7               The 48 Laws of Power by Robert Greene           93
# 8   Beyond the Story: 10-Year Record of BTS Book b...           65
# 9            The Psychology of Money by Morgan Housel          135
# 10                           verity by Colleen Hoover          108
# 11                            the psychology of money           39
# 12  it startswith us #it ends withus by Colleen Ho...           13
# 13  Yaaram Yaram Complete Novel by Sumaira Hameed ...           35
# 14                     it end with us by Collen hover           86
#
#    Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0              NaN            98                     97                 NaN
# 1              NaN            82                    100                  55
# 2               99            80                    100                  58
# 3              NaN            81                    100                  75
# 4              NaN            87                    100                  80
# 5              NaN            88                    100                 NaN
# 6               99            89                    100                  11
# 7               99            91                    100                  17
# 8               99            89                    100                  35
# 9              NaN            87                    100                  81
# 10             NaN            88                    100                  12
# 11             NaN            82                    100                  75
# 12             NaN            82                    100                  67
# 13             NaN            87                    100                  55
# 14             NaN            88                    100                 NaN
#
#    Selling_Price Original_Price Chat_Responce_Rate
# 0            300            NaN                100
# 1            400            895                 86
# 2            628           1500                 97
# 3            250            999                100
# 4            899           4499                100
# 5           1045            NaN                 88
# 6            979           1099                 98
# 7            499            599                 91
# 8            587            899                 98
# 9            329           1699                100
# 10           199            225                 88
# 11           225            895                 86
# 12           410           1245                 86
# 13           809           1799                100
# 14           199            NaN                 88

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4081 entries, 0 to 4080
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   4080 non-null   object
#  1   People_Review           4081 non-null   object
#  2   Deliver_Charges         714 non-null    object
#  3   Seller_Rating           4081 non-null   object
#  4   Shipping_Timing_Rating  4081 non-null   object
#  5   Discount_Percentage     3763 non-null   object
#  6   Selling_Price           4081 non-null   object
#  7   Original_Price          3763 non-null   object
#  8   Chat_Responce_Rate      4080 non-null   object
# dtypes: object(9)
# memory usage: 287.1+ KB

# %%
df.describe()
# Out:
#             Title People_Review Deliver_Charges Seller_Rating  \
# count        4080          4081             714          4081
# unique       1574           146              10            27
# top     Not Found                            99            87
# freq           38          1694             457           858
#
#        Shipping_Timing_Rating Discount_Percentage Selling_Price  \
# count                    4081                3763          4081
# unique                     24                  83           407
# top                       100                   1           299
# freq                     2812                 327           221
#
#        Original_Price Chat_Responce_Rate
# count            3763               4080
# unique            164                 30
# top              1999                100
# freq              560               2145

# %%
df = df.replace({'Title': {'Not Found':np.NaN}})

# %%
df['Title'].isna().sum()
# Out:
# 39

# %%
df.isna().sum()
# Out:
# Title                       39
# People_Review                0
# Deliver_Charges           3367
# Seller_Rating                0
# Shipping_Timing_Rating       0
# Discount_Percentage        318
# Selling_Price                0
# Original_Price             318
# Chat_Responce_Rate           1
# dtype: int64

# %%
df.head()
# Out:
#                                                Title People_Review  \
# 0  World Times The Political World Map Edited by ...          100
# 1               thik grow and rich#rich dad poor dad           61
# 2  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3       The Silent Patient Novel by Alex Michaelides           43
# 4  Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
#
#   Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0             NaN            98                     97                 NaN
# 1             NaN            82                    100                  55
# 2              99            80                    100                  58
# 3             NaN            81                    100                  75
# 4             NaN            87                    100                  80
#
#   Selling_Price Original_Price Chat_Responce_Rate
# 0           300            NaN                100
# 1           400            895                 86
# 2           628           1500                 97
# 3           250            999                100
# 4           899           4499                100

# %%
df = df.transpose()
df.head(30)
# Out:
#                                                                      0     \
# Title                   World Times The Political World Map Edited by ...
# People_Review                                                        100
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 97
# Discount_Percentage                                                   NaN
# Selling_Price                                                         300
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                         1     \
# Title                   thik grow and rich#rich dad poor dad
# People_Review                                            61
# Deliver_Charges                                          NaN
# Seller_Rating                                             82
# Shipping_Timing_Rating                                   100
# Discount_Percentage                                       55
# Selling_Price                                            400
# Original_Price                                           895
# Chat_Responce_Rate                                        86
#
#                                                                      2     \
# Title                   Peer e Kamil By umer Ahmed Best Selling Urdu Book
# People_Review                                                        113
# Deliver_Charges                                                        99
# Seller_Rating                                                          80
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    58
# Selling_Price                                                         628
# Original_Price                                                       1500
# Chat_Responce_Rate                                                     97
#
#                                                                 3     \
# Title                   The Silent Patient Novel by Alex Michaelides
# People_Review                                                    43
# Deliver_Charges                                                  NaN
# Seller_Rating                                                     81
# Shipping_Timing_Rating                                           100
# Discount_Percentage                                               75
# Selling_Price                                                    250
# Original_Price                                                   999
# Chat_Responce_Rate                                               100
#
#                                                                      4     \
# Title                   Rich Dad, Poor Dad / Atomic Habits /Think and ...
# People_Review                                                        238
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          87
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    80
# Selling_Price                                                         899
# Original_Price                                                       4499
# Chat_Responce_Rate                                                    100
#
#                                                                      5     \
# Title                   twisted #book1 love #2 game#3 hate#4lies combo...
# People_Review                                                         12
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          88
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                   NaN
# Selling_Price                                                        1045
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                     88
#
#                                                                      6     \
# Title                   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...
# People_Review                                                        138
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    11
# Selling_Price                                                         979
# Original_Price                                                       1099
# Chat_Responce_Rate                                                     98
#
#                                                          7     \
# Title                   The 48 Laws of Power by Robert Greene
# People_Review                                             93
# Deliver_Charges                                            99
# Seller_Rating                                              91
# Shipping_Timing_Rating                                    100
# Discount_Percentage                                        17
# Selling_Price                                             499
# Original_Price                                            599
# Chat_Responce_Rate                                         91
#
#                                                                      8     \
# Title                   Beyond the Story: 10-Year Record of BTS Book b...
# People_Review                                                         65
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    35
# Selling_Price                                                         587
# Original_Price                                                        899
# Chat_Responce_Rate                                                     98
#
#                                                             9     ...  \
# Title                   The Psychology of Money by Morgan Housel  ...
# People_Review                                               135   ...
# Deliver_Charges                                              NaN  ...
# Seller_Rating                                                 87  ...
# Shipping_Timing_Rating                                       100  ...
# Discount_Percentage                                           81  ...
# Selling_Price                                                329  ...
# Original_Price                                              1699  ...
# Chat_Responce_Rate                                           100  ...
#
#                                                                      4071  \
# Title                   The Forty Rules of Love by Elif Shafak Urdu Ed...
# People_Review                                                         63
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    23
# Selling_Price                                                         880
# Original_Price                                                       1150
# Chat_Responce_Rate                                                    100
#
#                                                                      4072  \
# Title                   You Can Become The Person You Want to be by Dr...
# People_Review                                                         53
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         400
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                        4073  \
# Title                   The power of your subconscious mind
# People_Review                                          412
# Deliver_Charges                                         119
# Seller_Rating                                            96
# Shipping_Timing_Rating                                  100
# Discount_Percentage                                       1
# Selling_Price                                           593
# Original_Price                                          599
# Chat_Responce_Rate                                       68
#
#                                                                   4074  \
# Title                   The Prince by Niccolo Machiavelli Urdu Edition
# People_Review                                                       5
# Deliver_Charges                                                    NaN
# Seller_Rating                                                       98
# Shipping_Timing_Rating                                              98
# Discount_Percentage                                                NaN
# Selling_Price                                                      400
# Original_Price                                                     NaN
# Chat_Responce_Rate                                                 100
#
#                                                              4075  \
# Title                   Simple Trading Book I Simple Trading Book
# People_Review                                                  4
# Deliver_Charges                                                99
# Seller_Rating                                                  89
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            73
# Selling_Price                                                1348
# Original_Price                                               5000
# Chat_Responce_Rate                                             87
#
#                                                              4076  \
# Title                   The Laws of Human Nature By Robert Greene
# People_Review                                                  6
# Deliver_Charges                                               NaN
# Seller_Rating                                                  87
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            78
# Selling_Price                                                 445
# Original_Price                                               1999
# Chat_Responce_Rate                                            100
#
#                                                                      4077  \
# Title                   Haraf Haraf Haqeeqat Urdu Book By Wasif Ali Wasif
# People_Review                                                          3
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         500
# Original_Price                                                        NaN
# Chat_Responce_Rate                                                    100
#
#                                                                      4078  \
# Title                   Shayad By Jon Elia in urdu Poetry Book Best Se...
# People_Review                                                        465
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                     1
# Selling_Price                                                         395
# Original_Price                                                        399
# Chat_Responce_Rate                                                     99
#
#                                                    4079  \
# Title                   Simple Trading Book(Novel Size)
# People_Review                                        4
# Deliver_Charges                                     NaN
# Seller_Rating
# Shipping_Timing_Rating                              100
# Discount_Percentage                                  20
# Selling_Price                                       682
# Original_Price                                      850
# Chat_Responce_Rate                                   93
#
#                                                                      4080
# Title                   Abraham Lincoln a Book By Sterling North Urdu ...
# People_Review
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    25
# Selling_Price                                                         300
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
# [9 rows x 4081 columns]

# %%
# Use a conditional statement to replace NaN values in the selected row with values from the row above
df.iloc[7] = df.iloc[6].where(df.iloc[7].isna(), df.iloc[7])
df.head(30)
# Out:
#                                                                      0     \
# Title                   World Times The Political World Map Edited by ...
# People_Review                                                        100
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 97
# Discount_Percentage                                                   NaN
# Selling_Price                                                         300
# Original_Price                                                        300
# Chat_Responce_Rate                                                    100
#
#                                                         1     \
# Title                   thik grow and rich#rich dad poor dad
# People_Review                                            61
# Deliver_Charges                                          NaN
# Seller_Rating                                             82
# Shipping_Timing_Rating                                   100
# Discount_Percentage                                       55
# Selling_Price                                            400
# Original_Price                                           895
# Chat_Responce_Rate                                        86
#
#                                                                      2     \
# Title                   Peer e Kamil By umer Ahmed Best Selling Urdu Book
# People_Review                                                        113
# Deliver_Charges                                                        99
# Seller_Rating                                                          80
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    58
# Selling_Price                                                         628
# Original_Price                                                       1500
# Chat_Responce_Rate                                                     97
#
#                                                                 3     \
# Title                   The Silent Patient Novel by Alex Michaelides
# People_Review                                                    43
# Deliver_Charges                                                  NaN
# Seller_Rating                                                     81
# Shipping_Timing_Rating                                           100
# Discount_Percentage                                               75
# Selling_Price                                                    250
# Original_Price                                                   999
# Chat_Responce_Rate                                               100
#
#                                                                      4     \
# Title                   Rich Dad, Poor Dad / Atomic Habits /Think and ...
# People_Review                                                        238
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          87
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    80
# Selling_Price                                                         899
# Original_Price                                                       4499
# Chat_Responce_Rate                                                    100
#
#                                                                      5     \
# Title                   twisted #book1 love #2 game#3 hate#4lies combo...
# People_Review                                                         12
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          88
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                   NaN
# Selling_Price                                                        1045
# Original_Price                                                       1045
# Chat_Responce_Rate                                                     88
#
#                                                                      6     \
# Title                   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...
# People_Review                                                        138
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    11
# Selling_Price                                                         979
# Original_Price                                                       1099
# Chat_Responce_Rate                                                     98
#
#                                                          7     \
# Title                   The 48 Laws of Power by Robert Greene
# People_Review                                             93
# Deliver_Charges                                            99
# Seller_Rating                                              91
# Shipping_Timing_Rating                                    100
# Discount_Percentage                                        17
# Selling_Price                                             499
# Original_Price                                            599
# Chat_Responce_Rate                                         91
#
#                                                                      8     \
# Title                   Beyond the Story: 10-Year Record of BTS Book b...
# People_Review                                                         65
# Deliver_Charges                                                        99
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                100
# Discount_Percentage                                                    35
# Selling_Price                                                         587
# Original_Price                                                        899
# Chat_Responce_Rate                                                     98
#
#                                                             9     ...  \
# Title                   The Psychology of Money by Morgan Housel  ...
# People_Review                                               135   ...
# Deliver_Charges                                              NaN  ...
# Seller_Rating                                                 87  ...
# Shipping_Timing_Rating                                       100  ...
# Discount_Percentage                                           81  ...
# Selling_Price                                                329  ...
# Original_Price                                              1699  ...
# Chat_Responce_Rate                                           100  ...
#
#                                                                      4071  \
# Title                   The Forty Rules of Love by Elif Shafak Urdu Ed...
# People_Review                                                         63
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    23
# Selling_Price                                                         880
# Original_Price                                                       1150
# Chat_Responce_Rate                                                    100
#
#                                                                      4072  \
# Title                   You Can Become The Person You Want to be by Dr...
# People_Review                                                         53
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         400
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
#                                                        4073  \
# Title                   The power of your subconscious mind
# People_Review                                          412
# Deliver_Charges                                         119
# Seller_Rating                                            96
# Shipping_Timing_Rating                                  100
# Discount_Percentage                                       1
# Selling_Price                                           593
# Original_Price                                          599
# Chat_Responce_Rate                                       68
#
#                                                                   4074  \
# Title                   The Prince by Niccolo Machiavelli Urdu Edition
# People_Review                                                       5
# Deliver_Charges                                                    NaN
# Seller_Rating                                                       98
# Shipping_Timing_Rating                                              98
# Discount_Percentage                                                NaN
# Selling_Price                                                      400
# Original_Price                                                     400
# Chat_Responce_Rate                                                 100
#
#                                                              4075  \
# Title                   Simple Trading Book I Simple Trading Book
# People_Review                                                  4
# Deliver_Charges                                                99
# Seller_Rating                                                  89
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            73
# Selling_Price                                                1348
# Original_Price                                               5000
# Chat_Responce_Rate                                             87
#
#                                                              4076  \
# Title                   The Laws of Human Nature By Robert Greene
# People_Review                                                  6
# Deliver_Charges                                               NaN
# Seller_Rating                                                  87
# Shipping_Timing_Rating                                        100
# Discount_Percentage                                            78
# Selling_Price                                                 445
# Original_Price                                               1999
# Chat_Responce_Rate                                            100
#
#                                                                      4077  \
# Title                   Haraf Haraf Haqeeqat Urdu Book By Wasif Ali Wasif
# People_Review                                                          3
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                   NaN
# Selling_Price                                                         500
# Original_Price                                                        500
# Chat_Responce_Rate                                                    100
#
#                                                                      4078  \
# Title                   Shayad By Jon Elia in urdu Poetry Book Best Se...
# People_Review                                                        465
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          89
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                     1
# Selling_Price                                                         395
# Original_Price                                                        399
# Chat_Responce_Rate                                                     99
#
#                                                    4079  \
# Title                   Simple Trading Book(Novel Size)
# People_Review                                        4
# Deliver_Charges                                     NaN
# Seller_Rating
# Shipping_Timing_Rating                              100
# Discount_Percentage                                  20
# Selling_Price                                       682
# Original_Price                                      850
# Chat_Responce_Rate                                   93
#
#                                                                      4080
# Title                   Abraham Lincoln a Book By Sterling North Urdu ...
# People_Review
# Deliver_Charges                                                       NaN
# Seller_Rating                                                          98
# Shipping_Timing_Rating                                                 98
# Discount_Percentage                                                    25
# Selling_Price                                                         300
# Original_Price                                                        400
# Chat_Responce_Rate                                                    100
#
# [9 rows x 4081 columns]

# %%
df = df.transpose()
df.head(30)
# Out:
#                                                 Title People_Review  \
# 0   World Times The Political World Map Edited by ...          100
# 1                thik grow and rich#rich dad poor dad           61
# 2   Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 3        The Silent Patient Novel by Alex Michaelides           43
# 4   Rich Dad, Poor Dad / Atomic Habits /Think and ...          238
# 5   twisted #book1 love #2 game#3 hate#4lies combo...           12
# 6   (Cat and Mouse Duet ) Haunting Adeline / _Hunt...          138
# 7               The 48 Laws of Power by Robert Greene           93
# 8   Beyond the Story: 10-Year Record of BTS Book b...           65
# 9            The Psychology of Money by Morgan Housel          135
# 10                           verity by Colleen Hoover          108
# 11                            the psychology of money           39
# 12  it startswith us #it ends withus by Colleen Ho...           13
# 13  Yaaram Yaram Complete Novel by Sumaira Hameed ...           35
# 14                     it end with us by Collen hover           86
# 15   The Intelligent Investor Book by Benjamin Graham           40
# 16          The Laws of Human Nature by Robert Greene           42
# 17                        ugly love by Colleen hoover           25
# 18                  it ends with us by Colleen Hoover           16
# 19       Peer e Kamil And Aab e Hayaat by umera Ahmed           95
# 20          The Art of Reading Minds by Henrik Fexeus           66
# 21              Peer E Kamil Urdu Book By Umera Ahmad           59
# 22             Haunting Adeline Book by H. D. Carlton           70
# 23            Atomic Habits by James Clear (Original)           37
# 24       Mein Kampf Book by Adolf Hitler Urdu Edition           13
# 25                       Allah_Loves by Omar Suleiman           86
# 26  The 7 Habits of Highly Effective People by Ste...           67
# 27                                                NaN
# 28                                                NaN
# 29   Fourth Wing (The Empyrean, #1) by Rebecca Yarros            6
#
#    Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 0              NaN            98                     97                 NaN
# 1              NaN            82                    100                  55
# 2               99            80                    100                  58
# 3              NaN            81                    100                  75
# 4              NaN            87                    100                  80
# 5              NaN            88                    100                 NaN
# 6               99            89                    100                  11
# 7               99            91                    100                  17
# 8               99            89                    100                  35
# 9              NaN            87                    100                  81
# 10             NaN            88                    100                  12
# 11             NaN            82                    100                  75
# 12             NaN            82                    100                  67
# 13             NaN            87                    100                  55
# 14             NaN            88                    100                 NaN
# 15             NaN            87                    100                  74
# 16              99            89                    100                  24
# 17             NaN            82                    100                  31
# 18             NaN            82                    100                  61
# 19             159            80                    100                  50
# 20             NaN            87                    100                  72
# 21              99            81                    100                 NaN
# 22              99            89                    100                  24
# 23             NaN            94                    100                  65
# 24             NaN            98                     97                  26
# 25             NaN            87                    100                  79
# 26             NaN            87                    100                  72
# 27                                                                      NaN
# 28                                                                      NaN
# 29              99            89                    100                  24
#
#    Selling_Price Original_Price Chat_Responce_Rate
# 0            300            300                100
# 1            400            895                 86
# 2            628           1500                 97
# 3            250            999                100
# 4            899           4499                100
# 5           1045           1045                 88
# 6            979           1099                 98
# 7            499            599                 91
# 8            587            899                 98
# 9            329           1699                100
# 10           199            225                 88
# 11           225            895                 86
# 12           410           1245                 86
# 13           809           1799                100
# 14           199            199                 88
# 15           517           1999                100
# 16           455            599                 98
# 17           275            399                 86
# 18           196            499                 86
# 19          1508           3000                 97
# 20           281            999                100
# 21           619            619                100
# 22           533            699                 98
# 23          1395           3995                100
# 24           445            600                100
# 25           375           1799                100
# 26           277            995                100
# 27
# 28
# 29           528            699                 98

# %% [markdown]
# ## Train Test Split

# %%
y = df['Selling_Price']
X = df.drop('Selling_Price', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=54)
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (3264, 3264, 817, 817)

# %%
X_train.head(10)
# Out:
#                                                   Title People_Review  \
# 2173  The Seven Husbands of Evelyn Hugo Novel by Tay...            1
# 2245  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 2367  Aab-E-Hayat urdu novel by Umera Ahmad Aab-E-Ha...          428
# 522                Reclaim Your Heart by Yasmin Mogahed
# 905                              The Darkest Temptation
# 2316  Master Your English – Direct Indirect Narratio...            3
# 1165            The 7 Habits Of Highly Effective People            1
# 1853  Hunting Adeline Novel by H. D. Carlton Best Se...            7
# 2606               Reclaim Your Heart by Yasmin Mogahed
# 1767  How to Stop Worrying and Start Living Book by ...           19
#
#      Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 2173             NaN                                   91                  56
# 2245              99            80                    100                  58
# 2367             NaN            89                     98                   1
# 522              NaN            87                    100                  81
# 905              NaN            86                    100                  70
# 2316             NaN            94                    100                   2
# 1165             NaN            91                     78                  50
# 1853             NaN            89                     98                   1
# 2606             NaN            87                    100                  81
# 1767             NaN            87                    100                  72
#
#      Original_Price Chat_Responce_Rate
# 2173            899                100
# 2245           1500                 97
# 2367            879                 99
# 522            1699                100
# 905             999                 92
# 2316            440                100
# 1165            599                 95
# 1853            379                 99
# 2606           1699                100
# 1767            995                100

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3264 entries, 2173 to 3183
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   3230 non-null   object
#  1   People_Review           3264 non-null   object
#  2   Deliver_Charges         572 non-null    object
#  3   Seller_Rating           3264 non-null   object
#  4   Shipping_Timing_Rating  3264 non-null   object
#  5   Discount_Percentage     3001 non-null   object
#  6   Original_Price          3264 non-null   object
#  7   Chat_Responce_Rate      3263 non-null   object
# dtypes: object(8)
# memory usage: 229.5+ KB

# %%
X_train = X_train.dropna(axis = 0, subset=['Title'], how='any')
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3230 entries, 2173 to 3183
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   3230 non-null   object
#  1   People_Review           3230 non-null   object
#  2   Deliver_Charges         541 non-null    object
#  3   Seller_Rating           3230 non-null   object
#  4   Shipping_Timing_Rating  3230 non-null   object
#  5   Discount_Percentage     2997 non-null   object
#  6   Original_Price          3230 non-null   object
#  7   Chat_Responce_Rate      3230 non-null   object
# dtypes: object(8)
# memory usage: 227.1+ KB

# %%
X_train.head()
# Out:
#                                                   Title People_Review  \
# 2173  The Seven Husbands of Evelyn Hugo Novel by Tay...            1
# 2245  Peer e Kamil By umer Ahmed Best Selling Urdu Book          113
# 2367  Aab-E-Hayat urdu novel by Umera Ahmad Aab-E-Ha...          428
# 522                Reclaim Your Heart by Yasmin Mogahed
# 905                              The Darkest Temptation
#
#      Deliver_Charges Seller_Rating Shipping_Timing_Rating Discount_Percentage  \
# 2173             NaN                                   91                  56
# 2245              99            80                    100                  58
# 2367             NaN            89                     98                   1
# 522              NaN            87                    100                  81
# 905              NaN            86                    100                  70
#
#      Original_Price Chat_Responce_Rate
# 2173            899                100
# 2245           1500                 97
# 2367            879                 99
# 522            1699                100
# 905             999                 92

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
encoding_trans = Pipeline(steps=
                             [
                                 ('encode', OneHotEncoder(drop='first', sparse_output = False, dtype = np.int32))
                             ])
inputingDeCh = Pipeline(steps=
                    [
                        ('simpleImZaro', SimpleImputer(missing_values = np.nan, strategy='constant', fill_value=0))
                    ])
inputingPeRe = Pipeline(steps=[
                        ('simpleImMean', SimpleImputer(missing_values = np.nan, strategy = 'mean'))
                    ])

                    
col_trans = ColumnTransformer(transformer_weights=
                              [
                                ('Encoder', encoding_trans,[0]),
                                ('ImputerZero', imputingDeCh, [1, 2, 5]),
                                ('ImputeMean', imputingPeRe, [3,4,7])
                              ])
model = Pipeline(steps=[('preprocessor', preprocessor),
                        ('scaling', StandardScaler()),
                        ('regressor', LinearRegression())
                        ])
model.fit(X_train, y_train)

# Step 6: Make Predictions
y_pred = model.predict(X_test)
# Step 7: Evaluate the Model
# Coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

# Evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Coefficients: {coefficients}')
print(f'Intercept: {intercept}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/iqbal/project/MLCode.ipynb Cell 21 line 2
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> inputingDeCh = Pipeline(steps=
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a>                     [
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=13'>14</a>                         ('simpleImZaro', SimpleImputer(missing_values = np.nan, strategy='constant', fill_value=0))
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=14'>15</a>                     ])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=15'>16</a> inputingPeRe = Pipeline(steps=
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=16'>17</a>                     [
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=17'>18</a>                         ('simpleImMean', SimpleImputer(missing_values = np.nan, strategy = 'mean'))
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=18'>19</a>                     ])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=19'>20</a> col_trans = ColumnTransformer(transformer_weights=
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=20'>21</a>                               [
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=21'>22</a>                                 ('Encoder', encoding_trans,[0]),
# ---> <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a>                                 ('ImputerZero', imputingDeCh, [1, 2, 5]),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=23'>24</a>                                 ('ImputeMean', imputingPeRe, [3,4,7])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a>                               ])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=25'>26</a> model = Pipeline(steps=[('preprocessor', preprocessor),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=26'>27</a>                         ('scaling', StandardScaler()),
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=27'>28</a>                         ('regressor', LinearRegression())
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=28'>29</a>                         ])
#      <a href='vscode-notebook-cell:/home/iqbal/project/MLCode.ipynb#X24sZmlsZQ%3D%3D?line=29'>30</a> model.fit(X_train, y_train)
#
# NameError: name 'imputingDeCh' is not defined
